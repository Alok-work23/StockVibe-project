# %%
import pandas as pd

df = pd.read_csv("combined_stock_dataset.csv")

print(df.shape)
print(df.columns)
print(df.head())
# Out:
# (5348, 22)
# Index(['Date', 'avg_sentiment', 'message_count', 'avg_likes', 'avg_replies',
#        'avg_reposts', 'price', 'negative', 'neutral', 'positive',
#        'positive_ratio', 'negative_ratio', 'neutral_ratio', 'company',
#        'next_price', 'target', 'price_return_1d', 'price_return_3d',
#        'price_return_7d', 'sentiment_3d_avg', 'sentiment_7d_avg',
#        'volume_change'],
#       dtype='object')
#          Date  avg_sentiment  message_count  avg_likes  avg_replies  \
# 0  2023-09-04       0.822516             44   0.295455     0.136364
# 1  2023-09-05       0.818667             33   0.363636     0.060606
# 2  2023-09-06       0.832592             25   0.280000     0.200000
# 3  2023-09-07       0.826911             18   0.388889     0.111111
# 4  2023-09-08       0.822524             17   0.470588     0.000000
#
#    avg_reposts        price  negative  neutral  positive  ...  neutral_ratio  \
# 0     0.000000  2469.604248         1       40         3  ...       0.909091
# 1     0.030303  2493.044678         1       31         1  ...       0.939394
# 2     0.080000  2495.493652         5       18         2  ...       0.720000
# 3     0.055556  2508.488525         2       13         3  ...       0.722222
# 4     0.058824  2518.284424         1       13         3  ...       0.764706
#
#              company   next_price target  price_return_1d  price_return_3d  \
# 0  Adani_Enterprises  2493.044678      1         0.008388         0.008388
# 1  Adani_Enterprises  2495.493652      1         0.009492         0.017959
# 2  Adani_Enterprises  2508.488525      1         0.000982         0.018959
# 3  Adani_Enterprises  2518.284424      1         0.005207         0.015745
# 4  Adani_Enterprises  2518.284424      0         0.003905         0.010124
#
#    price_return_7d  sentiment_3d_avg  sentiment_7d_avg  volume_change
# 0        -0.000748          0.785635          0.796895       1.444444
# 1        -0.004947          0.801124          0.796786      -0.250000
# 2        -0.006605          0.824592          0.800842      -0.242424
# 3         0.037305          0.826057          0.802841      -0.280000
# 4         0.028265          0.827342          0.808228      -0.055556
#
# [5 rows x 22 columns]

# %%
print(df["target"].value_counts())
print(df["target"].value_counts(normalize=True))
# Out:
# target
# 0    3405
# 1    1943
# Name: count, dtype: int64
# target
# 0    0.636687
# 1    0.363313
# Name: proportion, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("combined_stock_dataset.csv")

print(df["target"].value_counts())
print(df["target"].value_counts(normalize=True))
# Out:
# target
# 0    4115
# 1    1233
# Name: count, dtype: int64
# target
# 0    0.769447
# 1    0.230553
# Name: proportion, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("combined_stock_dataset.csv")

print(df["return_pct"].describe())
# Out:
# count    5348.000000
# mean        0.000315
# std         0.013520
# min        -0.226068
# 25%        -0.003687
# 50%         0.000000
# 75%         0.004249
# max         0.169149
# Name: return_pct, dtype: float64
