# %%
import pandas as pd

df = pd.read_csv("Adani_Enterprises_Forum_data.csv")

df["Date"] = pd.to_datetime(df["Date"])

print("Rows:", len(df))
print("Unique days:", df["Date"].nunique())
print("Min date:", df["Date"].min())
print("Max date:", df["Date"].max())
# Out:
# Rows: 10000
# Unique days: 563
# Min date: 2023-08-28 00:00:00
# Max date: 2025-05-01 00:00:00
